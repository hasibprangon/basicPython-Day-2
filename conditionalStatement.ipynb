# %% [markdown]
# # Conditional Statement

# %%
raining = True

if not raining :
    print("Play Football")

else:
    print("Play video games")
# Out:
# Play video games

# %% [markdown]
# ## Nested If else

# %%
raining = input()
muddy = input()

if raining: 
    if muddy:
        print("Play football & be safe")
    else: 
        print("play football")

else:
    print("Play video games")
# Out:
# Play football & be safe

# %% [markdown]
# ## Else If

# %%
money = int(input())

if money >= 500 :
    print("Going with friends")
elif money <= 400 :
    print("Order food")
elif money <= 300 :
    print("Cook food")
else :
    print("Save the money")
# Out:
# Order food

# %% [markdown]
# ## continue and break

# %%
sum = 0

for i in range(1, 11):
    print(i, "is processing....")
    
    if(i % 2 == 0):
        continue
    sum += i
    print(i, "is added to the sum")
    

print(sum)
# Out:
# 1 is processing....
# 1 is added to the sum
# 2 is processing....
# 3 is processing....
# 3 is added to the sum
# 4 is processing....
# 5 is processing....
# 5 is added to the sum
# 6 is processing....
# 7 is processing....
# 7 is added to the sum
# 8 is processing....
# 9 is processing....
# 9 is added to the sum
# 10 is processing....
# 25
